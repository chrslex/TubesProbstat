# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# IMPORT FILE NI BOS
data = pd.read_csv("gandum.csv", header = None)
data.set_axis(["Id", "Daerah", "SumbuUtama", "SumbuKecil", "Keunikan", "AreaBulatan", "Diameter", "KadarAir"
              , "Keliling", "Bulatan", "Ransum", "Kelas"], axis = 1, inplace = True)
data.set_index("Id", inplace = True)
data.head()
# Out:
#     Daerah  SumbuUtama  SumbuKecil  Keunikan  AreaBulatan   Diameter  \
# Id
# 1     5781  128.288875   58.470846  0.890095         5954  85.793926
# 2     4176  109.348294   49.837688  0.890098         4277  72.918093
# 3     4555  114.427991   52.151207  0.890105         4706  76.155145
# 4     4141  108.701190   49.457349  0.890499         4236  72.611879
# 5     5273  122.747868   55.757848  0.890876         5431  81.937733
#
#     KadarAir  Keliling   Bulatan    Ransum  Kelas
# Id
# 1   0.674090   316.756  0.724041  2.194066      1
# 2   0.596231   260.346  0.774227  2.194088      1
# 3   0.776641   279.606  0.732159  2.194158      1
# 4   0.633180   260.478  0.766961  2.197877      1
# 5   0.669842   302.730  0.723031  2.201446      1

# %%
# 1. Descriptive Analysis untuk setiap kolom
print("MEAN untuk setiap kolom") 
print()
print(data.mean())
print()
print("MEDIAN untuk setiap kolom")
print()
print(data.median())
print()
print("MODUS untuk setiap kolom")
print(data.mode())
print()
print("Standar deviasi untuk setiap kolom")
print()
print(data.std())
print()
print("Variansi untuk setiap kolom")
print()
print(data.var())
print()
print("Range untuk setiap kolom")
print()
print(data.max()  - data.min())
print()
print("Nilai minimum untuk setiap kolom")
print(data.min())
print()
print("Nilai maksimum untuk setiap kolom")
print()
print(data.max())
print()
print("Kuartil untuk setiap kolom")
data.describe().iloc[4:7]
print()
print("IQR untuk setiap kolom")
Q3 = data.quantile(0.75)
Q1 = data.quantile(0.25)
print(Q3 - Q1)
print()
print("Skewness untuk setiap kolom")
print()
print(data.skew())
print()
print("Kurtosis untuk setiap kolom")
print()
print(data.kurt())
# Out:
# MEAN untuk setiap kolom
#
# Daerah         4801.246000
# SumbuUtama      116.045171
# SumbuKecil       53.715246
# Keunikan          0.878764
# AreaBulatan    4937.048000
# Diameter         77.771158
# KadarAir          0.648372
# Keliling        281.479722
# Bulatan           0.761737
# Ransum            2.150915
# Kelas             1.502000
# dtype: float64
#
# MEDIAN untuk setiap kolom
#
# Daerah         4735.000000
# SumbuUtama      115.405140
# SumbuKecil       53.731199
# Keunikan          0.890045
# AreaBulatan    4857.000000
# Diameter         77.645277
# KadarAir          0.626117
# Keliling        280.045500
# Bulatan           0.761288
# Ransum            2.193599
# Kelas             2.000000
# dtype: float64
#
# MODUS untuk setiap kolom
#      Daerah  SumbuUtama  SumbuKecil  Keunikan  AreaBulatan   Diameter  \
# 0    3992.0   74.133114   39.906517  0.719916       3802.0  71.293564
# 1    4881.0   74.364021   41.436419  0.725553       4913.0  78.833256
# ...

# %% [markdown]
# # 2. Distribution Plot and Box Plot

# %%
## a. Kolom Daerah
df_sumbu = data.loc[:, "Daerah"]
plt.figure(figsize=(10,10))
plt.hist(df_sumbu)
plt.show()
# KOMENTAR : Daerah paling banyak terdapat diantara daerah 4000 dan 6000, sedangkan daerah dibawah 3000 dan di atas 7000 hanya sedikit data
plt.figure(figsize=(10,10))
plt.boxplot(df_sumbu)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Daerah":
# - Daerah paling banyak terdapat diantara daerah 4000 dan 6000, sedangkan daerah dibawah 3000 dan di atas 7000 hanya sedikit data
# - Daerah tidak memiliki outlier
# - Memliki kuartil 1 - kuartil 3 dari sekitar 4000 sampai 5500
# - Nilai minimim 2522 dan maksimum 7453

# %%
## a. Kolom SumbuUtama
df = data.loc[:, "SumbuUtama"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 20)
plt.show()
# KOMENTAR : 
plt.figure(figsize=(10,10))
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Sumbu Utama":
# - memliki kuartil 1 - kuartil 3 yaitu sekitar 104 sampai sekitar 129
# - memiliki outliers dikarenakan terdapat nilai yang melebihi 1.5*interquartile range
# - nilai minimim sekitar 74 dan maksimum sekitar 228

# %%
## a. Kolom SumbuKecil
df = data.loc[:, "SumbuKecil"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 20)
plt.show()
# KOMENTAR : 
plt.figure(figsize=(10,10))
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Sumbu Kecil":
# - memliki kuartil 1 - kuartil 3 yaitu sekitar 51.2 sampai sekitar 56.3
# - memiliki outliers dikarenakan terdapat nilai yang melebihi 1.5*interquartile range
# - nilai minimim sekitar 40 dan maksimum sekitar 69

# %%
## a. Kolom Keunikan
df = data.loc[:, "Keunikan"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 30)
plt.show()
# KOMENTAR : 
plt.figure(figsize=(10,10))
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Keunikan":
# - memliki kuartil 1 - kuartil 3 yaitu sekitar 0.8636 sampai sekitar 0.9075
# - memiliki outliers dikarenakan terdapat nilai yang melebihi 1.5*interquartile range
# - nilai minimim sekitar 0.719 dan maksimum sekitar 0.914

# %%
## a. Kolom AreaBulatan
df = data.loc[:, "AreaBulatan"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 30)
plt.show()
# KOMENTAR :
plt.figure(figsize=(10,10)) 
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Area  Bulatan":
# - memliki kuartil 1 - kuartil 3 yaitu sekitar 4170 sampai sekitar 5654
# - tidak memliki outlier
# - nilai minimim 2579 dan maksimum 7720

# %%
## a. Kolom Diameter
df = data.loc[:, "Diameter"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 30)
plt.show()
# KOMENTAR : 
plt.figure(figsize=(10,10))
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Diameter":
# - memliki kuartil 1 - kuartil 3 yaitu sekitar 71.745 sampai sekitar 83.648
# - tidak memliki outlier
# - nilai minimim sekitar 56.667 dan maksimum sekitar 97.413

# %%
## a. Kolom KadarAir
df = data.loc[:, "KadarAir"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 30)
plt.show()
# KOMENTAR : 
plt.figure(figsize=(10,10))
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "KadarAir":
# - memliki kuartil 1 - kuartil 3 yaitu sekitar 0.5726 sampai sekitar 0.7266
# - tidak memliki outlier
# - nilai minimim sekitar 0.41 dan maksimum sekitar 0.879

# %%
## a. Kolom Keliling
df = data.loc[:, "Keliling"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 30)
plt.show()
# KOMENTAR : 
plt.figure(figsize=(10,10))
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Keliling":
# - memliki kuartil 1 - kuartil 3 yaitu sekitar 225.88 sampai sekitar 306.06
# - memiliki outliers dikarenakan terdapat nilai yang melebihi 1.5*interquartile range
# - nilai minimim sekitar 197.015 dan maksimum sekitar 488.83

# %%
## a. Kolom Bulatan
df = data.loc[:, "Bulatan"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 30)
plt.show()
# KOMENTAR : 
plt.figure(figsize=(10,10))
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Bulatan":
# - memliki kuartil 1 - kuartil 3 yaitu sekitar 0.73199 sampai sekitar 0.79636
# - memiliki outliers dikarenakan terdapat nilai yang melebihi 1.5*interquartile range
# - nilai minimim sekitar 0.1746 dan maksimum sekitar 0.9047

# %%
## a. Kolom Ransum
df = data.loc[:, "Ransum"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 30)
plt.show()
# KOMENTAR : 
plt.figure(figsize=(10,10))
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Ransum":
# - memliki kuartil 1 - kuartil 3 yaitu sekitar 1.9839 sampai sekitar 2.3816
# - tidak memliki outlier
# - nilai minimim sekitar 1.4407 dan maksimum sekitar 2.4648

# %%
## a. Kolom Kelas
df = data.loc[:, "Kelas"]
plt.figure(figsize=(10,10))
plt.hist(df, bins = 30)
plt.show()
# KOMENTAR : 
plt.figure(figsize=(10,10))
plt.boxplot(df)
plt.show()
# KOMENTAR

# %% [markdown]
# ### Penjelasan singkat tentang plot kolom "Kelas":
# - Tidak Memliki outlier
# - Minimum 1 dan Maksimum 2

# %% [markdown]
# # 3. Normality Test
# Menggunakan metode Shapiro-Wilk

# %%
from scipy.stats import shapiro

# %%
# Kolom daerah
df_checked1 = data["Daerah"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"Daerah\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "Daerah" adalah,  W : 0.9907860159873962 p = 0.003270698245614767

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p < 0.05 (0.003270698245614767), sehingga Shapiro-Wilk test menyatakan bahwa data tidak berdistribusi normal, karena nilai p secara signifikan jauh lebih kecil dari 0.05."

# %%
# Kolom SumbuUtama
df_checked1 = data["SumbuUtama"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"SumbuUtama\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "SumbuUtama" adalah,  W : 0.9513812065124512 p = 9.236201213569384e-12

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p < 0.05 (9.236201213569384e-12), sehingga Shapiro-Wilk test menyatakan bahwa data tidak berdistribusi normal, karena nilai p secara signifikan jauh lebih kecil dari 0.05."

# %%
# Kolom SumbuKecil
df_checked1 = data["SumbuKecil"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"SumbuKecil\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "SumbuKecil" adalah,  W : 0.996778666973114 p = 0.4234558641910553

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p > 0.05 (0.4234558641910553), sehingga Shapiro-Wilk test menyatakan bahwa data berdistribusi normal, karena nilai p secara signifikan jauh lebih besar dari 0.05."

# %%
# Kolom Keunikan
df_checked1 = data["Keunikan"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"Keunikan\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "Keunikan" adalah,  W : 0.8309029340744019 p = 1.3151663082081454e-22

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p < 0.05 (1.3151663082081454e-22), sehingga Shapiro-Wilk test menyatakan bahwa data tidak berdistribusi normal, karena nilai p secara signifikan jauh lebih kecil dari 0.05."

# %%
# Kolom AreaBulatan
df_checked1 = data["AreaBulatan"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"AreaBulatan\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "AreaBulatan" adalah,  W : 0.990435779094696 p = 0.0024847122840583324

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p < 0.05 (0.0024847122840583324), sehingga Shapiro-Wilk test menyatakan bahwa data tidak berdistribusi normal, karena nilai p secara signifikan jauh lebih kecil dari 0.05."

# %%
# Kolom Diameter
df_checked1 = data["Diameter"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"Diameter\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "Diameter" adalah,  W : 0.9951366186141968 p = 0.11834503710269928

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p > 0.05 (0.11834503710269928), sehingga Shapiro-Wilk test menyatakan bahwa data berdistribusi normal, karena nilai p secara signifikan jauh lebih besar dari 0.05."

# %%
# Kolom KadarAir
df_checked1 = data["KadarAir"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"KadarAir\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "KadarAir" adalah,  W : 0.9466671347618103 p = 1.959499836695633e-12

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p < 0.05 (1.959499836695633e-12), sehingga Shapiro-Wilk test menyatakan bahwa data tidak berdistribusi normal, karena nilai p secara signifikan jauh lebih kecil dari 0.05."

# %%
# Kolom Keliling
df_checked1 = data["Keliling"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"Keliling\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "Keliling" adalah,  W : 0.9692449569702148 p = 9.728394090302572e-09

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p < 0.05 (9.728394090302572e-09), sehingga Shapiro-Wilk test menyatakan bahwa data tidak berdistribusi normal, karena nilai p secara signifikan jauh lebih kecil dari 0.05."

# %%
# Kolom Bulatan
df_checked1 = data["Bulatan"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"Bulatan\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "Bulatan" adalah,  W : 0.7697757482528687 p = 6.899158691421287e-26

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p < 0.05 (6.899158691421287e-26), sehingga Shapiro-Wilk test menyatakan bahwa data tidak berdistribusi normal, karena nilai p secara signifikan jauh lebih kecil dari 0.05."

# %%
# Kolom Ransum
df_checked1 = data["Ransum"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"Ransum\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "Ransum" adalah,  W : 0.9265043139457703 p = 6.245541108888591e-15

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p < 0.05 (6.245541108888591e-15), sehingga Shapiro-Wilk test menyatakan bahwa data tidak berdistribusi normal, karena nilai p secara signifikan jauh lebih kecil dari 0.05."

# %%
# Kolom Kelas
df_checked1 = data["Kelas"]
W, p = shapiro(df_checked1)
print("Shapiro Wilk-Test untuk kolom \"Kelas\" adalah,  W : {} p = {}".format(W,p))
# Out:
# Shapiro Wilk-Test untuk kolom "Kelas" adalah,  W : 0.6365421414375305 p = 3.5514183439331154e-31

# %% [markdown]
# #### "Dari nilai Shapiro-Wilk Test diatas, nilai p < 0.05 (3.5514183439331154e-31), sehingga Shapiro-Wilk test menyatakan bahwa data tidak berdistribusi normal, karena nilai p secara signifikan jauh lebih kecil dari 0.05."

# %% [markdown]
# # 4. Hypothesis Test

# %%
import math
import scipy.stats as st
import numpy as np
"""
Determined before that significant values(alpha) is 0.05
"""
one_sided_zVal_right = st.norm.ppf(.95)
one_sided_zVal_left = st.norm.ppf(.05)
two_sided_zVal = st.norm.ppf(.975)

print("One sided zVal right " + str(one_sided_zVal_right))
print("One sided zVal left " + str(one_sided_zVal_left))
print("Two sided zVal " + str(two_sided_zVal))
# Out:
# One sided zVal right 1.6448536269514722
# One sided zVal left -1.6448536269514729
# Two sided zVal 1.959963984540054

# %% [markdown]
# ## A. Menjawab "Nilai rata-rata daerah diatas 4700 ?"

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 = μ <= 4700
# - H1 = μ > 4700
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 1 sided, rata-rata dan standar deviasi dari populasi juga diketahui, jadi akan digunakan z-test dengan nilai kritikal z > 1.6449

# %%
# Proses mengambil data mean dan standar deviasi dari populasi
df_daerah = data["Daerah"]
# Inisialisasi data hipotesis
hypMean = 4700
popStd = df_daerah.std()
# Proses mengambil sampel, sebanyak 150
df_daerah_sample = np.random.choice(df_daerah, 218)
df_daerah_sample_mean = df_daerah_sample.mean()
# Mengambil z-score
z_score = (df_daerah_sample_mean - hypMean) / (popStd / math.sqrt(218))

print("z_score_sample adalah = " + str(z_score))
print("p_value_sample adalah = " + str(st.norm.sf(abs(z_score))))
# Out:
# z_score_sample adalah = 1.4831136287903957
# p_value_sample adalah = 0.06902211180327138

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample 0.20203097971703676 secara signifikan jauh lebih besar dari koefisien alpha yaitu 0.05
# dan z_score_sample berada di luar daerah kritis (z < - 1.6449) yaitu 0.8343887415306006 sehingga bisa disimpulkan bahwa
# ### H0 ditolak , pernyataan nilai rata-rata daerah di atas 4700 *BENAR*

# %%
df_sumbu = data.loc[:, "Daerah"]
plt.figure(figsize=(10,10))
plt.boxplot(df_sumbu)
plt.show()

# %% [markdown]
# ## B. Menjawab "Nilai rata-rata sumbu utama tidak sama dengan 116"

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 = μ  = 116
# - H1 = μ ≠ 116
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 2 sided, rata-rata dan standar deviasi dari populasi juga diketahui, jadi akan digunakan z-test dengan daerah kritikal z < -1.959963984540054 atau z > 1.959963984540054

# %%
# Proses mengambil data mean dan standar deviasi dari populasi
df_SumbuUtama = data["SumbuUtama"]
# Inisialisasi data hipotesis
hypMean = 116
popStd = df_SumbuUtama.std()
# Proses mengambil sampel, sebanyak 150
df_SumbuUtama_sample = np.random.choice(df_SumbuUtama, 218)
# Proses mengambil rata-rata dari sample
df_SumbuUtama_sample_mean = df_SumbuUtama_sample.mean()
# Mengambil z-score
z_score = (df_SumbuUtama_sample_mean - hypMean) / (popStd / math.sqrt(218))

print("z_score_sample adalah = " + str(z_score))
print("p_value_sample adalah = " + str(st.norm.sf(abs(z_score)) * 2))
# Out:
# z_score_sample adalah = -0.3323358649011264
# p_value_sample adalah = 0.7396356611237647

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample 0.49803558915274193 secara signifikan jauh lebih besar dari koefisien alpha yaitu 0.05
# dan z_score_sample berada di luar daerah kritis (z < -1.959963984540054 atau z > 1.959963984540054) yaitu 0.6775838494269542 sehingga bisa disimpulkan bahwa
# ### H0 dapat diterima, pernyataan Nilai rata-rata sumbu utama tidak sama dengan 116 SALAH (* karena H0 adalah μ = 116 )

# %%
df_sumbu = data.loc[:, "SumbuUtama"]
plt.figure(figsize=(10,10))
plt.boxplot(df_sumbu)
plt.show()

# %% [markdown]
# ## C. Menjawab "Nilai Rata-rata 20 baris pertama kolom Sumbu Kecil bukan 50 ? "

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 = μ  = 50
# - H1 = μ ≠ 50
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 2 sided, rata-rata dan standar deviasi dari populasi juga diketahui. Namun, ukuran sampel lebih kecil dari 30 (dianggap tidak berdistribusi Normal) dan data tidak dipilih secara random.
# - Nilai kritis untuk t-test 2 sided dengan tingkat signifikan 0.05 adalah t < -2.093024 atau t > 2.093024

# %%
# Proses mengambil data mean dari 20 data populasi pertama
df_SumbuKecil = data["SumbuKecil"][:20]
# Inisialisasi data hipotesis
hypMean = 50
# Proses mengambil 218 data sampel, sebanyak 20 data pertama
df_SumbuKecil_sample = np.random.choice(df_SumbuKecil, 218)[:20]
# Proses mengambil standard deviation dan rata-rata dari sample
sampleStd = df_SumbuKecil_sample.std()
df_SumbuKecil_sample_mean = df_SumbuKecil_sample.mean()
# Mengambil t-score 
t_score = (df_SumbuKecil_sample_mean - hypMean) / (sampleStd / math.sqrt(20))
# Mengambil p-score
p_val_from_tscore = st.t.sf(abs(t_score), 19) 
print("t_score_sample adalah = " + str(t_score))
print("p_value_sample adalah = {0:.7f}" .format(p_val_from_tscore * 2))
# Out:
# t_score_sample adalah = 7.734991791204365
# p_value_sample adalah = 0.0000003

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample 0.0000217 jauh lebih kecil dari koefisien alpha yaitu 0.05
# dan t_score_sample berada di dalam daerah kritis (t < -2.093024 atau t > 2.093024) yaitu 5.5881327445698075 disimpulkan bahwa
#
# ### H0 ditolak , pernyataan "Nilai Rata-rata 20 baris pertama kolom Sumbu Kecil bukan 50 ? " BENAR

# %%
df_sumbu = data.loc[:, "SumbuKecil"][:20]
plt.figure(figsize=(10,10))
plt.boxplot(df_sumbu)
plt.show()

# %% [markdown]
# ## D. Menjawab "Proporsi nilai Diameter yang lebih dari 85, adalah tidak sama dengan 15% "

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 = p  = 15 %
# - H1 = p ≠ 15 %
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 2 sided, rata-rata dan standar deviasi dari populasi juga diketahui, jadi akan digunakan proportion test dengan metode z-score dengan daerah kritikal z < -1.959963984540054 atau z > 1.959963984540054

# %%
# Inisialisasi p0 dan q0 
n_population_decimal_hypotesis = 0.15 #p0
complement_npopdec_hypothesis = 1 - n_population_decimal_hypotesis #q0
# Proses mengambil sampel
df_sample = data.sample(n = 218)
# Mengambil jumlah nilai diameter yang lebih dari 85 di kolom Diameter dari sampel
df_sample_processed = df_sample.loc[df_sample.Diameter > 85]
n_sample = len(df_sample_processed)
# Mencari p-complement
n_sample_decimal = n_sample / len(df_sample)
z_score = (n_sample_decimal - n_population_decimal_hypotesis) / (math.sqrt((n_population_decimal_hypotesis * complement_npopdec_hypothesis) / len(df_sample)))
print("z_score_sample adalah = " + str(z_score))
print("p_value_sample adalah = " + str(st.norm.sf(abs(z_score)) * 2))
# Out:
# z_score_sample adalah = 1.5743263092309299
# p_value_sample adalah = 0.11541203043137122

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample 0.006679923858582463 jauh lebih kecil dari koefisien alpha yaitu 0.05
# dan z_score_sample berada di dalam daerah kritis (z < -1.959963984540054 atau z > 1.959963984540054) yaitu 2.712393520723168 disimpulkan bahwa
#
# ### H0 ditolak, pernyataan "Proporsi nilai Diameter yang lebih dari 85, adalah tidak sama dengan 15% " *BENAR  (*karena p ≠ 15 % )

# %%
df_sumbu = data.loc[data.Diameter > 85 ]["Diameter"]
plt.figure(figsize=(10,10))
plt.boxplot(df_sumbu)
plt.show()

# %% [markdown]
# ## E. Menjawab "Proporsi nilai Keliling yang kurang dari 100, adalah kurang dari 5% ?"

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 = p >= 5 %
# - H1 = p < 5 %
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 1 sided, rata-rata dan standar deviasi dari populasi juga diketahui, jadi akan digunakan proportion test dengan metode z-score dengan daerah kritikal z < - 1.6448536269514722

# %%
# Inisialisasi p0 dan q0 
n_population_decimal_hypotesis = 0.05 #p0
complement_npopdec_hypothesis = 1 - n_population_decimal_hypotesis #q0
# Proses mengambil sampel
df_sample = data.sample(n = 218)
# Mengambil jumlah nilai keliling yang kurang dari 100 di kolom Keliling dari sampel
df_sample_processed = df_sample.loc[df_sample.Keliling < 100]
n_sample = len(df_sample_processed)
# Mencari p-complement
n_sample_decimal = n_sample / len(df_sample)
z_score = (n_sample_decimal - n_population_decimal_hypotesis) / (math.sqrt((n_population_decimal_hypotesis * complement_npopdec_hypothesis) / len(df_sample)))
print("z_score_sample adalah = " + str(z_score))
print("p_value_sample adalah = " + str(st.norm.sf(abs(z_score))))
# Out:
# z_score_sample adalah = -3.387282717832439
# p_value_sample adalah = 0.0003529430303822529

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample 0.0003529430303822529 jauh lebih kecil dari koefisien alpha yaitu 0.05
# dan z_score_sample berada di dalam daerah kritis (z <= - 1.6448536269514722) yaitu -3.387282717832439 disimpulkan bahwa
#
# ### H0 ditolak, pernyataan "Proporsi nilai Keliling yang kurang dari 100, adalah kurang dari 5% ?" BENAR

# %%
df_sumbu = data.loc[data.Keliling < 100]["Keliling"]
plt.figure(figsize=(10,10))
plt.boxplot(df_sumbu)
plt.show()

# %% [markdown]
# # 5. Hypothesis Testing 2

# %%
import statsmodels
from statsmodels.stats import weightstats, proportion

# %% [markdown]
# ## A. Menjawab "Data kolom AreaBulatan dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata kedua bagian tersebut sama?"

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 : μ1 = μ2 -> μ1 - μ2 = 0
# - H1 : μ1 ≠ μ2
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 2 sided, rata-rata dan standar deviasi dari populasi juga diketahui, dan ukuran sampel yang cukup besar jadi akan digunakan z-test dengan daerah kritikal z < -1.959963984540054 atau z > 1.959963984540054

# %%
# Mengambil data
half = len(data["AreaBulatan"]) // 2
# real
df_bulatan1 = data["AreaBulatan"][:half]
df_bulatan1_mean = df_bulatan1.mean()
df_bulatan1_std = df_bulatan1.std()
df_bulatan2 = data["AreaBulatan"][half:]
df_bulatan2_mean = df_bulatan2.mean()
df_bulatan2_std = df_bulatan2.std()
# test
df_test = data.sample(n = 300)
df_bulatan1_test = df_test["AreaBulatan"][: len(df_test)//2]
df_bulatan1_test_mean = df_bulatan1_test.mean()
df_bulatan1_test_std = df_bulatan1_test.std()
df_bulatan2_test = df_test["AreaBulatan"][len(df_test)//2 :]
df_bulatan2_test_mean = df_bulatan2_test.mean()
df_bulatan2_test_std = df_bulatan2_test.std()
# Inisialisasi hypothetical mean difference
mean_diff = 0.0
# Mengambil z-score
x, y = statsmodels.stats.weightstats.ztest(df_bulatan1_test, df_bulatan2_test, value = mean_diff)
print("z-score = {}, p-val = {}".format(x,y))
# Out:
# z-score = 2.0782300988873423, p-val = 0.0376881711089438

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample 0.0376881711089438 jauh lebih kecil dari koefisien alpha yaitu 0.05
# dan z_score_sample berada di dalam kritis (z < -1.959963984540054 atau z > 1.959963984540054) yaitu 2.0782300988873423 disimpulkan bahwa
#
# ### H0 ditolak, pernyataan "Data kolom AreaBulatan dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata kedua bagian tersebut sama?" SALAH

# %%
plt.figure(figsize=(10,10))
plt.boxplot(df_bulatan1)
plt.show()
plt.figure(figsize=(10,10))
plt.boxplot(df_bulatan2)
plt.show()

# %% [markdown]
# ## B. Menjawab "Data kolom Kadar Air dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata bagian awal lebih besar dari pada bagian akhir sebesar 0.2?"

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 : μ1 - μ2 = 0.2
# - H1 : μ1 - μ2 ≠ 0.2
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 2 sided, rata-rata dan standar deviasi dari populasi juga diketahui, dan ukuran sampel yang cukup besar jadi akan digunakan z-test dengan daerah kritikal z < -1.959963984540054 atau z > 1.959963984540054

# %%
# Mengambil data
half = len(data["KadarAir"]) // 2
# real
df_kadar1 = data["KadarAir"][:half]
df_kadar1_mean = df_kadar1.mean()
df_kadar1_std = df_kadar1.std()
df_kadar2 = data["KadarAir"][half:]
df_kadar2_mean = df_kadar2.mean()
df_kadar2_std = df_kadar2.std()
# test
df_test = data.sample(n = 218)
df_kadar1_test = df_test["KadarAir"][: len(df_test)//2]
df_kadar1_test_mean = df_kadar1_test.mean()
df_kadar1_test_std = df_kadar1_test.std()
df_kadar2_test = df_test["KadarAir"][len(df_test)//2 :]
df_kadar2_test_mean = df_kadar2_test.mean()
df_kadar2_test_std = df_kadar2_test.std()
# Inisialisasi hypothetical mean difference
mean_diff = 0.2
# Mengambil z-score
x, y = statsmodels.stats.weightstats.ztest(df_kadar1_test, df_kadar2_test, value = mean_diff)
print("z-score = {}, p-val = {}".format(x,y))
# Out:
# z-score = -15.945870697271111, p-val = 3.0436821572289086e-57

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample 3.0436821572289086e-57 jauh lebih kecil dari koefisien alpha yaitu 0.05
# dan z_score_sample berada di dalam kritis (z < -1.959963984540054 atau z > 1.959963984540054) yaitu -15.945870697271111 disimpulkan bahwa
#
# ### H0 ditolak, pernyataan "Data kolom Kadar Air dibagi 2 sama rata: bagian awal dan bagian akhir kolom. Benarkah rata-rata bagian awal lebih besar dari pada bagian akhir sebesar 0.2?" SALAH

# %%
plt.figure(figsize=(10,10))
plt.boxplot(df_kadar1)
plt.show()
plt.figure(figsize=(10,10))
plt.boxplot(df_kadar2)
plt.show()

# %% [markdown]
# ## C. Menjawab "Rata-rata 20 baris pertama kolom Bulatan sama dengan 20 baris terakhirnya?"

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 : μ1 - μ2 = 0.0
# - H1 : μ1 - μ2 ≠ 0.0
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 2 sided, rata-rata dan standar deviasi dari populasi juga diketahui. Namun data relatif kecil dan tidak diambil secara random, maka akan digunakan t-test
# - Nilai kritis untuk t-test 2 sided dengan tingkat signifikan 0.05 adalah t < -2.093024 atau t > 2.093024

# %%
# real
df_bulatan1 = data["Bulatan"][:20]
df_bulatan1_mean = df_bulatan1.mean()
df_bulatan1_std = df_bulatan1.std()
df_bulatan2 = data["Bulatan"][-20:]
df_bulatan2_mean = df_bulatan2.mean()
df_bulatan2_std = df_bulatan2.std()
# test
df_test = data.sample(n = 218)
df_bulatan1_test = df_test["Bulatan"][: 20]
df_bulatan1_test_mean = df_bulatan1_test.mean()
df_bulatan1_test_std = df_bulatan1_test.std()
df_bulatan2_test = df_test["Bulatan"][-20 :]
df_bulatan2_test_mean = df_bulatan2_test.mean()
df_bulatan2_test_std = df_bulatan2_test.std()
# Inisialisasi hypothetical mean difference
meanHypeDiff = 0.0
# Mengambil t-score
x, y, z = statsmodels.stats.weightstats.ttest_ind(df_bulatan1_test, df_bulatan2_test, value = 0, alternative = "two-sided")
print("t-score = {}, p-val = {}, dengan degree of freedom = {}".format(x,y,z))
# Out:
# t-score = 0.6271506055423599, p-val = 0.5343108353621222, dengan degree of freedom = 38.0

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample  0.5343108353621222 jauh lebih besar dari koefisien alpha yaitu 0.05
# dan t_score_sample berada di luar kritis (t < -2.093024 atau t > 2.093024) yaitu 0.6271506055423599, disimpulkan bahwa
#
# ### H0 diterima, pernyataan "Rata-rata 20 baris pertama kolom Bulatan sama dengan 20 baris terakhirnya?" BENAR

# %%
plt.figure(figsize=(10,10))
plt.boxplot(df_bulatan1)
plt.show()
plt.figure(figsize=(10,10))
plt.boxplot(df_bulatan2)
plt.show()

# %% [markdown]
# ## D. Menjawab "Proporsi nilai bagian awal Ransum yang lebih dari 2, adalah lebih besar daripada, proporsi nilai yang sama di bagian akhir Ransum?"

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 : p1 >= p2
# - H1 : p1 < p2
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 2 sided, rata-rata dan standar deviasi dari populasi juga diketahui. Namun data relatif kecil dan tidak diambil secara random, maka akan digunakan t-test
# - Nilai kritis untuk z-test 2 sided dengan tingkat signifikan 0.05 adalah z < -1.959963984540054

# %%
# Definisi half
half = len(data["Ransum"]) // 2
# real
df_ransum1 = data[:half]
df_ransum1 = df_ransum1.loc[df_ransum1.Ransum > 2]["Ransum"]
df_ransum1_mean = df_ransum1.mean()
df_ransum1_std = df_ransum1.std()
df_ransum2 = data[half:]
df_ransum2 = df_ransum2.loc[df_ransum2.Ransum > 2]["Ransum"]
df_ransum2_mean = df_ransum2.mean()
df_ransum2_std = df_ransum2.std()
# test 
df_test = data.sample(n = 218)
df_ransum1_test = df_test[:len(df_test) // 2]
df_ransum1_test_processed = df_ransum1_test.loc[df_ransum1_test.Ransum > 2]["Ransum"]
# Bagian awal kolom
df_ransum1_count = len(df_ransum1_test_processed)
df_ransum1_test_mean = df_ransum1_test.mean()
df_ransum1_test_std = df_ransum1_test.std()
df_ransum2_test = df_test[len(df_test) // 2:]
df_ransum2_test_processed = df_ransum2_test.loc[df_ransum2_test.Ransum > 2]["Ransum"]
# Bagian akhir kolom
df_ransum2_count = len(df_ransum2_test_processed)
df_ransum2_test_mean = df_ransum2_test.mean()
df_ransum2_test_std = df_ransum2_test.std()
# Proses z-score
z_score, p_val = statsmodels.stats.proportion.proportions_ztest([df_ransum1_count, df_ransum2_count], [len(df_ransum1_test), len(df_ransum2_test)], alternative = "larger")
print(z_score, p_val)
# Out:
# 0.6130759079963242 0.26991307468239234

# %%
plt.figure(figsize=(10,10))
plt.boxplot(df_ransum1)
plt.show()
plt.figure(figsize=(10,10))
plt.boxplot(df_ransum2)
plt.show()

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample 0.6130759079963242 jauh lebih besar dari koefisien alpha yaitu 0.05
# dan z_score_sample berada di luar kritis (z < - 1.6448536269514722) yaitu 0.26991307468239234, disimpulkan bahwa
#
# ### H0 diterima, pernyataan "Proporsi nilai bagian awal Ransum yang lebih dari 2, adalah lebih besar daripada, proporsi nilai yang sama di bagian akhir Ransum?" BENAR

# %% [markdown]
# ## E. Menjawab "Bagian awal kolom Diameter memiliki variansi yang sama dengan bagian akhirnya ?"

# %% [markdown]
# #### Menentukan Hipotesis 0 dan Hipotesis alternatif
# - H0 : (σ^2)1 = (σ^2)2
# - H1 : (σ^2)1 ≠ (σ^2)2
#
# #### Menentukan tingkat signifikan
# - α = 0.05
#
# #### Menentukan uji statistik yang digunakan dan nilai kritis
# - Karena hipotesis alternatif adalah 2 sided, rata-rata dan standar deviasi dari populasi juga diketahui. Namun data relatif kecil dan tidak diambil secara random, maka akan digunakan t-test
# - Nilai kritis untuk f-test 2 sided dengan tingkat signifikan 0.05 adalah f < -1.37430772 atau f > 1.37430772

# %%
# Mengambil data
half = len(data["Diameter"]) // 2
# real
df_diameter1 = data["Diameter"][:half]
df_diameter1_mean = df_diameter1.mean()
df_diameter1_std = df_diameter1.std()
df_diameter1_var = df_diameter1.var()
df_diameter2 = data["Diameter"][half:]
df_diameter2_mean = df_diameter2.mean()
df_diameter2_std = df_diameter2.std()
df_diameter2_var = df_diameter2.var()
# test
df_test = data.sample(n = 218)
df_diameter1_test = df_test["Diameter"][: len(df_test)//2]
df_diameter1_test_mean = df_diameter1_test.mean()
df_diameter1_test_std = df_diameter1_test.std()
df_diameter2_test = df_test["Diameter"][len(df_test)//2 :]
df_diameter2_test_mean = df_diameter2_test.mean()
df_diameter2_test_std = df_diameter2_test.std()
# Getting f value
def f_test(x, y):
    x = np.array(x)
    y = np.array(y)
    f = np.var(x, ddof=1)/np.var(y, ddof=1) #calculate F test statistic 
    dfn = x.size-1 #define degrees of freedom numerator 
    dfd = y.size-1 #define degrees of freedom denominator 
    p = 1-st.f.cdf(f, dfn, dfd) #find p-value of F test statistic 
    return f, p
f_val, p_val = f_test(df_diameter1_test, df_diameter2_test)
print("f-score = {}, p-value = {}".format(f_val, p_val))
# Out:
# f-score = 1.3970756349967697, p-value = 0.04186205056173187

# %% [markdown]
# #### Penentuan hasil
# Didapat bahwa p_value_sample 0.04186205056173187 jauh lebih kecil dari koefisien alpha yaitu 0.05
# dan f_score_sample berada di luar kritis (f < -1.37430772 atau f > 1.37430772) yaitu 1.3970756349967697, disimpulkan bahwa
#
# ### H0 ditolak, pernyataan "Bagian awal kolom Diameter memiliki variansi yang sama dengan bagian akhirnya ?" SALAH

# %%
plt.figure(figsize=(10,10))
plt.boxplot(df_diameter1)
plt.show()
plt.figure(figsize=(10,10))
plt.boxplot(df_diameter2)
plt.show()

# %% [markdown]
# # 6. Correlation Test

# %%
target = data["Kelas"]

# %% [markdown]
# ## A. Korelasi Daerah dengan Kelas

# %%
test = data["Daerah"]
matrix_coef = np.corrcoef(test, target)
matrix_coef
# Out:
# array([[ 1.        , -0.60274665],
#        [-0.60274665,  1.        ]])

# %% [markdown]
# ### Nilai korelasi pearson adalah -0.60274665, lebih dekat ke -1 sehingga data berkolerasi secara terbalik dengan dengan level sedang, Daerah dengan Id yang besar cenderung memiliki kelas 1 dibanding 2

# %%
plt.figure(figsize=(10,10))
plt.scatter(test, target)
plt.show()

# %% [markdown]
# ## B. Korelasi SumbuUtama dengan Kelas

# %%
test = data["SumbuUtama"]
matrix_coef = np.corrcoef(test, target)
matrix_coef
# Out:
# array([[ 1.        , -0.71309061],
#        [-0.71309061,  1.        ]])

# %% [markdown]
# ### Nilai korelasi pearson adalah -0.71309061, berarti SumbuUtama dan kelas berkorelasi secara terbalik dengan level cukup kuat, Sumbu Utama dengan nilai yang besar cenderung ada di kelas  dan sebaliknya

# %%
plt.figure(figsize=(10,10))
plt.scatter(test,target, linestyle='solid')
plt.show()

# %% [markdown]
# ## C. Korelasi SumbuKecil dengan Kelas

# %%
test = data["SumbuKecil"]
matrix_coef = np.corrcoef(test, target)
matrix_coef
# Out:
# array([[ 1.        , -0.15297517],
#        [-0.15297517,  1.        ]])

# %% [markdown]
# ### Nilai korelasi pearson antara SumbuKecil dengan Kelas adalah -0.15297517, berarti sumbu kecil dengan kelas mempunyai hubungan terbalik dengan level sangat lemah, hampir tidak ada korelasi.

# %%
plt.figure(figsize=(10,10))
plt.scatter(test,target)
plt.show()

# %% [markdown]
# ## D. Korelasi Keunikan dengan Kelas

# %%
test = data["Keunikan"]
matrix_coef = np.corrcoef(test, target)
matrix_coef
# Out:
# array([[ 1.        , -0.73045637],
#        [-0.73045637,  1.        ]])

# %% [markdown]
# ### Nilai korelasi pearson adalah -0.73045637, berarti kolom Keunikan dengan Kelas berkorelasi secara terbalik dengan level yang cukup kuat. Nilai keunikan yang tinggi cenderung berada di kelas 1.

# %%
plt.figure(figsize=(10,10))
plt.scatter(test,target)
plt.show()

# %% [markdown]
# ## E. Korelasi AreaBulatan dengan Kelas

# %%
test = data["AreaBulatan"]
matrix_coef = np.corrcoef(test, target)
matrix_coef
# Out:
# array([[ 1.        , -0.60731254],
#        [-0.60731254,  1.        ]])

# %% [markdown]
# ### Koefisien korelasi adalah -0.60731254, menandakan kedua kolom berkorelasi dengan level sedang secara terbalik(negatif), AreaBulatan dengan nilai yang besar banyak berada di kelas 1

# %%
plt.figure(figsize=(10,10))
plt.scatter(test,target)
plt.show()

# %% [markdown]
# ## F. Korelasi Diameter dengan Kelas

# %%
test = data["Diameter"]
matrix_coef = np.corrcoef(test, target)
matrix_coef
# Out:
# array([[ 1.        , -0.60253569],
#        [-0.60253569,  1.        ]])

# %% [markdown]
# ### Nilai korelasi kedua kolom yang bersangkutan adalah -0.60253569, sehingga kedua kolom berkorelasi secara terbalik dengan level yang cukup kuat, Diameter tinggi cenderung ada di kelas 1

# %%
plt.figure(figsize=(10,10))
plt.scatter(test,target)
plt.show()

# %% [markdown]
# ## G. Korelasi Kadar Air dengan Kelas

# %%
test = data["KadarAir"]
matrix_coef = np.corrcoef(test, target)
matrix_coef
# Out:
# array([[1.        , 0.13434423],
#        [0.13434423, 1.        ]])

# %% [markdown]
# ### Nilai koefisien korelasi adalah 0.13434423, sehingga kedua kolom berkorelasi secara lurus dengan level yang sangat lemah, hampir tidak mempunyai korelasi

# %%
plt.figure(figsize=(10,10))
plt.scatter(test,target)
plt.show()

# %% [markdown]
# ## H. Korelasi Bulatan dengan Kelas

# %%
test = data["Bulatan"]
matrix_coef = np.corrcoef(test, target)
matrix_coef
# Out:
# array([[1.        , 0.54500453],
#        [0.54500453, 1.        ]])

# %% [markdown]
# ### Nilai koefisien korelasi adalah 0.54500453, berarti kedua kolom berkorelasi secara lurus dengan level sedang, Peningkatan jumlah bulatan cenderung berada di kelas 2

# %%
plt.figure(figsize=(10,10))
plt.scatter(test,target)
plt.show()

# %% [markdown]
# ## I. Korelasi Ransum dengen Kelas

# %%
test = data["Ransum"]
matrix_coef = np.corrcoef(test, target)
matrix_coef
# Out:
# array([[ 1.        , -0.83990387],
#        [-0.83990387,  1.        ]])

# %% [markdown]
# ### Nilai korelasi ransum dengan kelas adalah -0.83990387, sehingga ransum dengan kelas berbanding secara terbaik dengan level kuat. Semakin besar nilai ransum, maka cenderung berada di kelas 1.

# %%
plt.figure(figsize=(10,10))
plt.scatter(test,target)
plt.show()
